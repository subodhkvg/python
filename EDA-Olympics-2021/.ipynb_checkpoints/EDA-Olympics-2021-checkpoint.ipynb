# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("athlete_events.csv")
region_df = pd.read_csv("noc_regions.csv")

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
region_df.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df.shape
# Out:
# (271116, 15)

# %%
region_df.shape
# Out:
# (230, 3)

# %%
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
#Dataframe is set to summer only. SO no. of rows has been deducted now
df[df['Season'] == 'Summer']
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 271106  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
#we can get region from NOC and merge it to the athelet data
#caution - executiong this command more than once will join NOC again and again causing region_x...region_y...ect
df = df.merge(region_df,on="NOC",how='left')

# %%
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal  region notes
# ...

# %%
#To calculate how many countries has participated, we need to get counts of region
df['NOC'].unique().shape
# Out:
# (230,)

# %%
df['region'].unique()
# Out:
# array(['China', 'Denmark', 'Netherlands', 'USA', 'Finland', 'Norway',
#        'Romania', 'Estonia', 'France', 'Morocco', 'Spain', 'Egypt',
#        'Iran', 'Bulgaria', 'Italy', 'Chad', 'Azerbaijan', 'Sudan',
#        'Russia', 'Argentina', 'Cuba', 'Belarus', 'Greece', 'Cameroon',
#        'Turkey', 'Chile', 'Mexico', 'Nicaragua', 'Hungary', 'Nigeria',
#        'Algeria', 'Kuwait', 'Bahrain', 'Pakistan', 'Iraq', 'Syria',
#        'Lebanon', 'Qatar', 'Malaysia', 'Germany', 'Canada', 'Ireland',
#        'Australia', 'South Africa', 'Eritrea', 'Tanzania', 'Jordan',
#        'Tunisia', 'Libya', 'Belgium', 'Djibouti', 'Palestine', 'Comoros',
#        'Kazakhstan', 'Brunei', 'India', 'Saudi Arabia', 'Maldives',
#        'Ethiopia', 'United Arab Emirates', 'Yemen', 'Indonesia',
#        'Philippines', nan, 'Uzbekistan', 'Kyrgyzstan', 'Tajikistan',
#        'Japan', 'Republic of Congo', 'Switzerland', 'Brazil', 'Monaco',
# ...

# %%
df['region'].unique().shape
# Out:
# (206,)

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# region       370
# notes     266077
# dtype: int64

# %%
#check duplicate rows in dataset
df.duplicated().sum()
# Out:
# 1385

# %%
#remove duplicate records
#inplace=True will amend the existing df
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Medal'].value_counts()
# Out:
# Gold      13369
# Bronze    13295
# Silver    13108
# Name: Medal, dtype: int64

# %%
#there are some Nan values in medal column
#so we need to do One-hot-encoding on it
#so it will provide diffrent column for each value present in medal column
pd.get_dummies(df['Medal'])
# Out:
#         Bronze  Gold  Silver
# 0            0     0       0
# 1            0     0       0
# 2            0     0       0
# 3            0     1       0
# 4            0     0       0
# ...        ...   ...     ...
# 271111       0     0       0
# 271112       0     0       0
# 271113       0     0       0
# 271114       0     0       0
# 271115       0     0       0
#
# [269731 rows x 3 columns]

# %%
#So, now we need to concatenate these dataframe to our existing dataframe
df.shape
# Out:
# (269731, 17)

# %%
df = pd.concat([df,pd.get_dummies(df['Medal'])],axis=1)

# %%
df.shape
# Out:
# (269731, 20)

# %%
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal  region notes  Bronze  \
# ...

# %%
df.groupby('NOC').sum()[['Gold','Silver','Bronze']].sort_values('Gold',ascending=False).reset_index().head(25)
#But the data mismatched with https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table
#Found 1 team 1 medal is also listed for each individual team member causing distribution per member hence rise in medal count
# Out:
#     NOC    Gold  Silver  Bronze
# 0   USA  2638.0  1641.0  1358.0
# 1   URS  1082.0   732.0   689.0
# 2   GER   745.0   674.0   746.0
# 3   GBR   677.0   739.0   651.0
# 4   ITA   575.0   531.0   531.0
# 5   FRA   499.0   602.0   666.0
# 6   SWE   479.0   522.0   535.0
# 7   CAN   463.0   438.0   451.0
# 8   HUN   432.0   332.0   371.0
# 9   GDR   397.0   327.0   281.0
# 10  RUS   390.0   367.0   408.0
# 11  NOR   378.0   361.0   294.0
# 12  CHN   350.0   347.0   292.0
# 13  AUS   348.0   455.0   517.0
# 14  NED   287.0   340.0   413.0
# 15  JPN   247.0   309.0   357.0
# 16  KOR   221.0   232.0   185.0
# 17  FIN   198.0   270.0   432.0
# 18  DEN   179.0   241.0   177.0
# 19  SUI   175.0   248.0   268.0
# 20  CUB   164.0   129.0   116.0
# 21  ROU   161.0   200.0   292.0
# 22  FRG   159.0   194.0   233.0
# 23  IND   138.0    19.0    40.0
# 24  YUG   130.0   167.0    93.0

# %%
df[(df['NOC'] == 'IND') & (df['Medal'] == 'Gold') & (df['Year']==1928) & (df['Sport']=='Hockey')].shape
#14 members of a same team are provided with gold medal, but it should be counted as a single medal
df[(df['NOC'] == 'IND') & (df['Medal'] == 'Gold') & (df['Year']==1928) & (df['Sport']=='Hockey')]
# Out:
#             ID                                   Name Sex   Age  Height  \
# 4732      2699                            Shaukat Ali   M  30.0     NaN
# 5032      2864                    Richard James Allen   M  25.0   172.0
# 38352    19716                       Dhyan Chand Bais   M  22.0   169.0
# 76886    39020                Michael Anthony Gateley   M  23.0     NaN
# 82144    41710  William James "Willie" Goodsir-Cullen   M  21.0     NaN
# 89524    45360                 Leslie Charles Hammond   M  23.0   184.0
# 116859   59150             Feroz-ud-Din "Feroze" Khan   M  23.0     NaN
# 150463   75490          George Eric McCarthy Marthins   M  22.0     NaN
# 173081   86987         Richard Alexander "Rex" Norris   M  28.0     NaN
# 189138   95008                   Broome Eric Pinniger   M  25.0   180.0
# 202266  101590                      Michael E. Rocque   M   NaN     NaN
# 215286  108082               Frederick Stephen Seaman   M  22.0     NaN
# ...

# %%
#So, we are removing duplicates as discussed above
medal_tally = df.drop_duplicates(subset=['Team','NOC','Games','Year','City','Sport','Event','Medal'])

# %%
medal_tally
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271095  135559          Pawe Jan Zygmunt   M  25.0   182.0    79.0
# 271096  135559          Pawe Jan Zygmunt   M  29.0   182.0    79.0
# 271097  135559          Pawe Jan Zygmunt   M  29.0   182.0    79.0
# 271098  135559          Pawe Jan Zygmunt   M  33.0   182.0    79.0
# 271099  135560         Stavroula Zygouri   F  36.0   171.0    63.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
medal_tally.groupby('NOC').sum()[['Gold','Silver','Bronze']].sort_values('Gold',ascending=False).reset_index()
# Out:
#      NOC    Gold  Silver  Bronze
# 0    USA  1131.0   901.0   792.0
# 1    URS   471.0   373.0   353.0
# 2    GER   321.0   345.0   341.0
# 3    GBR   289.0   321.0   312.0
# 4    FRA   265.0   287.0   334.0
# ..   ...     ...     ...     ...
# 225  LAO     0.0     0.0     0.0
# 226  AHO     0.0     1.0     0.0
# 227  LBR     0.0     0.0     0.0
# 228  LCA     0.0     0.0     0.0
# 229  LBA     0.0     0.0     0.0
#
# [230 rows x 4 columns]

# %%
medal_tally = medal_tally.groupby('NOC').sum()[['Gold','Silver','Bronze']].sort_values('Gold',ascending=False).reset_index()

# %%
medal_tally[medal_tally['NOC'] =='IND']
# Out:
#     NOC  Gold  Silver  Bronze
# 51  IND  10.0     7.0    12.0

# %%
medal_tally = df.drop_duplicates(subset=['Team','NOC','Games','Year','City','Sport','Event','Medal'])
medal_tally = medal_tally.groupby('region').sum()[['Gold','Silver','Bronze']].sort_values('Gold',ascending=False).reset_index()
#medal_tally['total'] = medal_tally['Gold'] + medal_tally['Silver'] + medal_tally['Bronze']

# %%
medal_tally
# Out:
#             region    Gold  Silver  Bronze
# 0              USA  1131.0   901.0   792.0
# 1           Russia   727.0   600.0   589.0
# 2          Germany   580.0   592.0   597.0
# 3               UK   289.0   321.0   312.0
# 4           France   265.0   287.0   334.0
# ..             ...     ...     ...     ...
# 200       Honduras     0.0     0.0     0.0
# 201         Guyana     0.0     0.0     1.0
# 202  Guinea-Bissau     0.0     0.0     0.0
# 203         Guinea     0.0     0.0     0.0
# 204        Liberia     0.0     0.0     0.0
#
# [205 rows x 4 columns]

# %%
medal_tally['total'] = medal_tally['Gold'] + medal_tally['Silver'] + medal_tally['Bronze']

# %%
medal_tally
# Out:
#             region    Gold  Silver  Bronze   total
# 0              USA  1131.0   901.0   792.0  2824.0
# 1           Russia   727.0   600.0   589.0  1916.0
# 2          Germany   580.0   592.0   597.0  1769.0
# 3               UK   289.0   321.0   312.0   922.0
# 4           France   265.0   287.0   334.0   886.0
# ..             ...     ...     ...     ...     ...
# 200       Honduras     0.0     0.0     0.0     0.0
# 201         Guyana     0.0     0.0     1.0     1.0
# 202  Guinea-Bissau     0.0     0.0     0.0     0.0
# 203         Guinea     0.0     0.0     0.0     0.0
# 204        Liberia     0.0     0.0     0.0     0.0
#
# [205 rows x 5 columns]
